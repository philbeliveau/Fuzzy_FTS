# %% [markdown]
# # This dataset is focus on hyperparameter tuning and at the end there is an example with multivariate forecasting
# - In fuzzy time series, what are the different parameter that we can tune?
# - How to assess the performance per combination of parameter?
# - What is the effect of the number of partition on the performance of the model?
# - At what point are we overfitting by increasing the # of partitions?
# - What is the effect of order on the performance and complexity of the model?
# - How can we deal with the effect of 0 in the series.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/philippebeliveau/Desktop/Bureau/Notebook_Jupyter_R/datah-m1-challange/sales.csv")

# %%
df.head()
# Out:
#          DATE  S100  I100  C100  C101  QTT
# 0  2017-01-08     0     0    12    76    2
# 1  2017-01-08     0     0    12   149    3
# 2  2017-01-08     0     0    12   256    3
# 3  2017-01-08     0     0    12   354    3
# 4  2017-01-08     0     0    13   149    2

# %%
df.shape[0]
# Out:
# 2749369

# %% [markdown]
# Starts in 2017 and end in 2021

# %%
plt.figure(figsize=(20,5))
plt.plot(df["QTT"])

plt.xlabel("Date")
plt.ylabel("QTT")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Number of zeros

# %%
df.eq(0).sum()
# Out:
# DATE        0
# S100    99850
# I100     8841
# C100     6601
# C101       89
# QTT         0
# dtype: int64

# %% [markdown]
# ## Transformation
# We can use pyFTS own transformations tool. Although, I am not sure how are we going to integrate our own transformation in the partionning function.

# %%
from pyFTS.common import Transformations

diff = Transformations.Differential(1)
fig = plt.subplots(figsize=(20,5))
plt.plot(diff.apply(df["QTT"].values), label="QTT")
pass

# %% [markdown]
# # Train test split
# Only the training data seems to be partionned.

# %% [markdown]
# ### Smaller set

# %%
df['DATE'] = pd.to_datetime(df["DATE"], format='%Y-%m-%d')
train = df.iloc[:300000]
test = df.iloc[300001:400000]

uni_train = train["QTT"].values
multi_train = train

uni_test = test['QTT'].values
multi_test = test

# %%
multi_train.head()
# Out:
#         DATE  S100  I100  C100  C101  QTT
# 0 2017-01-08     0     0    12    76    2
# 1 2017-01-08     0     0    12   149    3
# 2 2017-01-08     0     0    12   256    3
# 3 2017-01-08     0     0    12   354    3
# 4 2017-01-08     0     0    13   149    2

# %% [markdown]
# ### Bigger set

# %%
train = df.iloc[:2000000]
test = df.iloc[2000001:2749369]

uni_train = train["QTT"].values
multi_train = train

uni_test = test['QTT'].values
multi_test = test

# %% [markdown]
# # EDA
# ## Stationnarity test

# %%
from statsmodels.tsa.stattools import adfuller
rows = []
result = adfuller(uni_train)
rows.append([result[0], result[1], result[2], result[3], result[4]])
pd.DataFrame(rows,columns=['ADF Statistic','p-value','Cr. Val. 1%','Cr. Val. 5%','Cr. Val. 10%'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-af2abfc3243f> in <module>
#       3 rows =[]
#       4
# ----> 5 result = adfuller(uni_train)
#       6 row.extend(result)
#       7 row.extend([value for key, value in result.items()])
#
# NameError: name 'uni_train' is not defined

# %% [markdown]
# ## ACF

# %%
from statsmodels.tsa.stattools import acf

fig, ax = plt.subplots(nrows=1, ncols=1,figsize=[15,5])

ax.plot(acf(multi_train, nlags=24))
ax.set_title("Autocorrelation")
ax.set_ylabel("ACF")
ax.set_xlabel("LAG")

# %% [markdown]
# # Training phase

# %% [markdown]
# ## Multivariate Methods

# %%
from pyFTS.common import Util
from pyFTS.benchmarks import Measures
from pyFTS.partitioners import Grid,  Entropy #, Huarng
from pyFTS.models import hofts
from pyFTS.common import Membership as mf
from pyFTS.partitioners import CMeans, Grid, FCM, Huarng, Entropy, Util as pUtil
from pyFTS.data import Enrollments

# %%
from pyFTS.models.multivariate import common, variable, mvfts
from pyFTS.models.seasonal import partitioner as seasonal
from pyFTS.models.seasonal.common import DateTime
from pyFTS.partitioners import Grid

# %%
model = mvfts.MVFTS() # should be mvfts.MVFTS("")

fig, axes = plt.subplots(nrows=5, ncols=1,figsize=[15,20])

sp = {'seasonality': DateTime.day_of_year , 'names': ['Jan','Fev','Mar','Abr','Mai','Jun','Jul', 'Ago','Set','Out','Nov','Dez']}

month = variable.Variable("Month", data_label="DATE", partitioner=seasonal.TimeGridPartitioner, npart=12, 
                           data=multi_train, partitioner_specific=sp)
month.partitioner.plot(axes[4])
model.append_variable(month)

sp = {'seasonality': DateTime.day_of_month , 'names': [str(k) for k in range(0,30)]}

Date = variable.Variable("DATE", data_label="DATE", partitioner=seasonal.TimeGridPartitioner, npart=30, data=multi_train, partitioner_specific=sp)
Date.partitioner.plot(axes[0])
model.append_variable(Date)

c100 = variable.Variable("C100", data_label="C100", partitioner=Grid.GridPartitioner, npart=5, data=multi_train)
c100.partitioner.plot(axes[1])
model.append_variable(c100)

s100 = variable.Variable("S100", data_label="S100", partitioner=Grid.GridPartitioner, npart=5, alpha_cut=.0, data=multi_train) 
s100.partitioner.plot(axes[2])
model.append_variable(s100)

QTT = variable.Variable("QTT", data_label="QTT", partitioner=Grid.GridPartitioner, npart=5, data=multi_train) 
QTT.partitioner.plot(axes[3])
model.target_variable =QTT

plt.tight_layout()
# Out:
# /opt/anaconda3/envs/Fuzzy_TS/lib/python3.6/site-packages/pyFTS/models/seasonal/partitioner.py:200: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.xaxis.set_ticklabels(ticks)
# /opt/anaconda3/envs/Fuzzy_TS/lib/python3.6/site-packages/pyFTS/partitioners/partitioner.py:238: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.xaxis.set_ticklabels(ticks)

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,figsize=[15,10])
ax[0].plot(multi_train["QTT"].values, label="QTT")

ax[1].plot(multi_train["C100"].values, label="C100")
ax[1].plot(lues, label="S100")
multi_train["S100"].va
plt.show()

# %% [markdown]
# In our case we are not going to transform them.

# %% [markdown]
# # Model training

# %%
model.fit(multi_train)
forecasted = model.predict(multi_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-ae6ad4c59f2b> in <module>
# ----> 1 model.fit(multi_train)
#       2 forecasted = model.predict(multi_test)
#
# /opt/anaconda3/envs/Fuzzy_TS/lib/python3.6/site-packages/pyFTS/common/fts.py in fit(self, ndata, **kwargs)
#     382                         mdata = data[ct - self.order : ct + batch_size]
#     383
# --> 384                     self.train(mdata, **kwargs)
#     385
#     386                     if batch_save:
#
# /opt/anaconda3/envs/Fuzzy_TS/lib/python3.6/site-packages/pyFTS/models/multivariate/mvfts.py in train(self, data, **kwargs)
#     118         ndata = self.apply_transformations(data)
#     119
# --> 120         flrs = self.generate_flrs(ndata)
#     121         self.generate_flrg(flrs)
#     122
#
# /opt/anaconda3/envs/Fuzzy_TS/lib/python3.6/site-packages/pyFTS/models/multivariate/mvfts.py in generate_flrs(self, data)
#      91             data_point = self.format_data( data.loc[ix] )
#      92
# ---> 93             tmp_flrs = self.generate_lhs_flrs(data_point)
#      94
#      95             target_ix = data.index[ct]
#
# /opt/anaconda3/envs/Fuzzy_TS/lib/python3.6/site-packages/pyFTS/models/multivariate/mvfts.py in generate_lhs_flrs(self, data)
#      70         for vc, var in enumerate(self.explanatory_variables):
#      71             data_point = data[var.name]
# ---> 72             lags[var.name] = common.fuzzyfy_instance(data_point, var, tuples=False)
#      73
#      74         for path in product_dict(**lags):
#
# /opt/anaconda3/envs/Fuzzy_TS/lib/python3.6/site-packages/pyFTS/models/multivariate/common.py in fuzzyfy_instance(data_point, var, tuples)
#      44
#      45 def fuzzyfy_instance(data_point, var, tuples=True):
# ---> 46     fsets = var.partitioner.fuzzyfy(data_point, mode='sets', method='fuzzy', alpha_cut=var.alpha_cut)
#      47     if tuples:
#      48         return [(var.name, fs) for fs in fsets]
#
# /opt/anaconda3/envs/Fuzzy_TS/lib/python3.6/site-packages/pyFTS/partitioners/partitioner.py in fuzzyfy(self, data, **kwargs)
#     150         method = kwargs.get('method', 'fuzzy')
#     151
# --> 152         nearest = self.search(data, type='index')
#     153
#     154         mv = np.zeros(self.partitions)
#
# /opt/anaconda3/envs/Fuzzy_TS/lib/python3.6/site-packages/pyFTS/models/seasonal/partitioner.py in search(self, data, **kwargs)
#     163             self.build_index()
#     164
# --> 165         _, ix = self.kdtree.query([data, data, data], results)
#     166
#     167         ix = ix.tolist()
#
# /opt/anaconda3/envs/Fuzzy_TS/lib/python3.6/site-packages/scipy/spatial/kdtree.py in query(self, x, k, eps, p, distance_upper_bound)
#     529             return dd, ii
#     530         else:
# --> 531             hits = self.__query(x, k=k, eps=eps, p=p, distance_upper_bound=distance_upper_bound)
#     532             if k is None:
#     533                 return [d for (d,i) in hits], [i for (d,i) in hits]
#
# /opt/anaconda3/envs/Fuzzy_TS/lib/python3.6/site-packages/scipy/spatial/kdtree.py in __query(self, x, k, eps, p, distance_upper_bound)
#     377                     break
#     378                 # compute minimum distances to the children and push them on
# --> 379                 if x[node.split_dim] < node.split:
#     380                     near, far = node.less, node.greater
#     381                 else:
#
# KeyboardInterrupt:

# %%
forecasted = model.predict(multi_test, distributed=False)
# Out:
# /opt/anaconda3/envs/Fuzzy_TS/lib/python3.6/site-packages/pyFTS/models/multivariate/mvfts.py:154: RuntimeWarning: invalid value encountered in double_scalars
#   ret.append(np.dot(mv,mp.T)/np.sum(mv))

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,figsize=[15,10])
ax[0].plot(multi_test["QTT"].values, label="QTT")

ax[1].plot(multi_test["C100"].values, label="Product")
ax[1].plot(multi_test["S100"].values, label="Store")

ax[0].plot(forecasted)

plt.show()

# %% [markdown]
# ## Other model
# Ensemble methods
# - Silva, P. C. L et al. Probabilistic Forecasting with Seasonal Ensemble Fuzzy Time-Series XIII Brazilian Congress on Computational Intelligence, 2017. Rio de Janeiro, Brazil.
