# %% [markdown]
# # A short tutorial about Fuzzy Time Series
# Prof. Msc. Petrônio Cândido L. Silva
#
# [pyFTS - Fuzzy Time Series for Python](http://pyfts.github.io/pyFTS/)
#
# [MINDS - Machine Intelligence and Data Science Lab  ](http://www.minds.eng.ufmg.br/)
#
#
#
# <center>
# <table><tr><td> <a href="http://www.minds.eng.ufmg.br/"><img src="https://github.com/petroniocandido/pyFTS/raw/master/img/minds_logo_medium.jpeg" alt="MINDS - Machine Intelligence and Data Science Lab" width="100"/></a></td>
#   <td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# <td><a href="https://pyfts.github.io/pyFTS/"><img src="https://github.com/PYFTS/pyFTS/raw/master/img/logo_medium.png" alt="pyFTS - Fuzzy Time Series for Python" width="100"/></a></td>
# </tr>
# </table>
# </center>

# %% [markdown]
# ## Install pyFTS library

# %%
# !pip3 install -U git+https://github.com/PYFTS/pyFTS
# Out:
# Collecting git+https://github.com/PYFTS/pyFTS
#   Cloning https://github.com/PYFTS/pyFTS to /private/var/folders/ck/hjxynrwd7f74cn88t3sb1_j80000gn/T/pip-req-build-vhlb2i92
#   Running command git clone --filter=blob:none --quiet https://github.com/PYFTS/pyFTS /private/var/folders/ck/hjxynrwd7f74cn88t3sb1_j80000gn/T/pip-req-build-vhlb2i92
#   Resolved https://github.com/PYFTS/pyFTS to commit 4c77ecc73fa0888132ac3996ca7e1f519dcf2fc8
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /Users/philippebeliveau/miniforge3/lib/python3.10/site-packages (from pyFTS==1.7) (3.7.0)
# Requirement already satisfied: numpy in /Users/philippebeliveau/miniforge3/lib/python3.10/site-packages (from pyFTS==1.7) (1.24.2)
# Collecting pandas
#   Downloading pandas-2.0.1-cp310-cp310-macosx_11_0_arm64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 16.1 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: fonttools>=4.22.0 in /Users/philippebeliveau/miniforge3/lib/python3.10/site-packages (from matplotlib->pyFTS==1.7) (4.38.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/philippebeliveau/miniforge3/lib/python3.10/site-packages (from matplotlib->pyFTS==1.7) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/philippebeliveau/miniforge3/lib/python3.10/site-packages (from matplotlib->pyFTS==1.7) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/philippebeliveau/miniforge3/lib/python3.10/site-packages (from matplotlib->pyFTS==1.7) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/philippebeliveau/miniforge3/lib/python3.10/site-packages (from matplotlib->pyFTS==1.7) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/philippebeliveau/miniforge3/lib/python3.10/site-packages (from matplotlib->pyFTS==1.7) (9.4.0)
# Requirement already satisfied: packaging>=20.0 in /Users/philippebeliveau/miniforge3/lib/python3.10/site-packages (from matplotlib->pyFTS==1.7) (23.0)
# Requirement already satisfied: cycler>=0.10 in /Users/philippebeliveau/miniforge3/lib/python3.10/site-packages (from matplotlib->pyFTS==1.7) (0.11.0)
# Collecting pytz>=2020.1
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.3/502.3 kB 13.4 MB/s eta 0:00:0000:01
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 14.7 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /Users/philippebeliveau/miniforge3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->pyFTS==1.7) (1.16.0)
# Building wheels for collected packages: pyFTS
#   Building wheel for pyFTS (setup.py) ... done
#   Created wheel for pyFTS: filename=pyFTS-1.7-py3-none-any.whl size=217873 sha256=8d95b652033b4ab771f9180c945bb479470290fd216ce8d23ee97c93edaf7334
#   Stored in directory: /private/var/folders/ck/hjxynrwd7f74cn88t3sb1_j80000gn/T/pip-ephem-wheel-cache-m7azqhzk/wheels/7f/25/75/dd8f713bf48592da71e0441c7abdc1f5aa4d9645a6b7ee99d4
# Successfully built pyFTS
# Installing collected packages: pytz, tzdata, pandas, pyFTS
# Successfully installed pandas-2.0.1 pyFTS-1.7 pytz-2023.3 tzdata-2023.3

# %% [markdown]
# ## Other common imports

# %%
import warnings
warnings.filterwarnings('ignore')


import matplotlib.pylab as plt

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Data loading

# %%
from pyFTS.data import Enrollments

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[10,5])

df = Enrollments.get_dataframe()
plot(df['Year'],df['Enrollments'])

data = df['Enrollments'].values

# %% [markdown]
# ## Training procedure

# %% [markdown]
# ### Definition of the Universe of Discourse U & Linguistic variable creation
#
# The Universe of Discourse (U) partitioners are responsible for identifying U, split the partitions and create their fuzzy sets. There are several ways to partition U and this has a direct impact on the accuracy of the predictive model.
#
# For this example we are using grid partitioning, where all sets are equal. The default membership function is triangular.

# %%
from pyFTS.partitioners import Grid

fs = Grid.GridPartitioner(data=data,npart=10)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[15,5])

fs.plot(ax)

# %% [markdown]
# ### Fuzzyfication
#
# This is demo-only, and you do not need to explicitly run it. This entire process runs automatically within the fit function, which trains the model.

# %%
fuzzyfied = fs.fuzzyfy(data, method='maximum', mode='sets')

fuzzyfied
# Out:
# ['A1',
#  'A2',
#  'A2',
#  'A3',
#  'A4',
#  'A4',
#  'A4',
#  'A4',
#  'A5',
#  'A5',
#  'A5',
#  'A4',
#  'A4',
#  'A4',
#  'A4',
#  'A4',
#  'A5',
#  'A7',
#  'A8',
#  'A8',
#  'A8',
#  'A7']

# %% [markdown]
# ### Temporal patterns
#
# This is demo-only, and you do not need to explicitly run it. This entire process runs automatically within the fit function, which trains the model.

# %%
from pyFTS.common import FLR

patterns = FLR.generate_non_recurrent_flrs(fuzzyfied)

print([str(k) for k in patterns])
# Out:
# ['A1 -> A2', 'A2 -> A2', 'A2 -> A3', 'A3 -> A4', 'A4 -> A4', 'A4 -> A5', 'A5 -> A5', 'A5 -> A4', 'A5 -> A7', 'A7 -> A8', 'A8 -> A8', 'A8 -> A7']

# %% [markdown]
# ### Rule generation

# %%
from pyFTS.models import chen

model = chen.ConventionalFTS(partitioner=fs)
model.fit(data)
print(model)
# Out:
# Conventional FTS:
# A1 -> A2
# A2 -> A2,A3
# A3 -> A4
# A4 -> A4,A5
# A5 -> A4,A5,A7
# A8 -> A7,A8
# A7 -> A8

# %%
from pyFTS.common import Util

Util.plot_rules(model, size=[15,5] , rules_by_axis=10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-b48550ada919> in <module>
#       1 from pyFTS.common import Util
#       2
# ----> 3 Util.plot_rules(model, size=[15,5] , rules_by_axis=10)
#
# /opt/anaconda3/envs/Fuzzy_TS/lib/python3.6/site-packages/pyFTS/common/Util.py in plot_rules(model, size, axis, rules_by_axis, columns)
#     232
#     233             if ct % rules_by_axis == 0:
# --> 234                 draw_sets_on_axis(ax, model, size)
#     235
#     236         if not model.is_high_order:
#
# /opt/anaconda3/envs/Fuzzy_TS/lib/python3.6/site-packages/pyFTS/common/Util.py in draw_sets_on_axis(axis, model, size)
#     289     tmp = ['']
#     290     tmp.extend(model.partitioner.ordered_sets)
# --> 291     axis.set_xticklabels(tmp)
#     292     axis.set_ylim([model.partitioner.min, model.partitioner.max])
#     293     axis.set_yticks([model.sets[k].centroid for k in model.partitioner.ordered_sets])
#
# /opt/anaconda3/envs/Fuzzy_TS/lib/python3.6/site-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      61
#      62         def wrapper(self, *args, **kwargs):
# ---> 63             return get_method(self)(*args, **kwargs)
#      64
#      65         wrapper.__module__ = owner.__module__
#
# /opt/anaconda3/envs/Fuzzy_TS/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# /opt/anaconda3/envs/Fuzzy_TS/lib/python3.6/site-packages/matplotlib/axis.py in _set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1794         if fontdict is not None:
#    1795             kwargs.update(fontdict)
# -> 1796         return self.set_ticklabels(labels, minor=minor, **kwargs)
#    1797
#    1798     @cbook._make_keyword_only("3.2", "minor")
#
# /opt/anaconda3/envs/Fuzzy_TS/lib/python3.6/site-packages/matplotlib/axis.py in set_ticklabels(self, ticklabels, minor, **kwargs)
#    1716             if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
#    1717                 raise ValueError(
# -> 1718                     "The number of FixedLocator locations"
#    1719                     f" ({len(locator.locs)}), usually from a call to"
#    1720                     " set_ticks, does not match"
#
# ValueError: The number of FixedLocator locations (10), usually from a call to set_ticks, does not match the number of ticklabels (11).

# %% [markdown]
# ##  Forecasting procedure

# %% [markdown]
# ### Input value fuzzyfication
#
# This is demo-only, and you do not need to explicitly run it. This entire process runs automatically within the fit function, which trains the model.

# %%
fuzzyfied = fs.fuzzyfy(18876, method='maximum', mode='sets')

print(fuzzyfied)
# Out:
# A7

# %% [markdown]
# ### Find the compatible rules & Defuzzyfy

# %%
model.predict([18876])
# Out:
# [19366.460000000006]

# %% [markdown]
# ## Model's in sample performance

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[15,5])

forecasts = model.predict(data)
forecasts.insert(0,None)

orig, = plot(data, label="Original data")
pred, = plot(forecasts, label="Forecasts")

legend(handles=[orig, pred])

# %% [markdown]
# ## General Process

# %%
from pyFTS.data import Enrollments
from pyFTS.partitioners import Grid
from pyFTS.models import chen

train = Enrollments.get_data()

test = Enrollments.get_data()

#Universe of Discourse Partitioner
partitioner = Grid.GridPartitioner(data=train,npart=10)

# Create an empty model using the Chen(1996) method
model = chen.ConventionalFTS(partitioner=partitioner)

# The training procedure is performed by the method fit
model.fit(train)

#Print the model rules
print(model)

# The forecasting procedure is performed by the method predict
forecasts = model.predict(test)


#Plot 
plot(test)
plot(forecasts)
# Out:
# Conventional FTS:
# A1 -> A2
# A2 -> A2,A3
# A3 -> A4
# A4 -> A4,A5
# A5 -> A4,A5,A7
# A8 -> A7,A8
# A7 -> A8
