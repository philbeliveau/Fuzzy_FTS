# %% [markdown]
# # Daily minimum temperatures in ME
# https://www.kaggle.com/datasets/kankanashukla/daily-minimum-temperatures-in-me

# %%
# pip install src
# Out:
# Collecting git+https://github.com/FedericoGarza/fforma
#   Cloning https://github.com/FedericoGarza/fforma to /private/var/folders/dj/q5s8lngd1msdbb76w1tn9x1r0000gn/T/pip-req-build-g6jojoti
#   Running command git clone --filter=blob:none --quiet https://github.com/FedericoGarza/fforma /private/var/folders/dj/q5s8lngd1msdbb76w1tn9x1r0000gn/T/pip-req-build-g6jojoti
#   Resolved https://github.com/FedericoGarza/fforma to commit 160bb084cddd57b255637ae6a1f69a4418c28a69
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: fforma-FedericoGarza
#   Building wheel for fforma-FedericoGarza (setup.py) ... done
#   Created wheel for fforma-FedericoGarza: filename=fforma_FedericoGarza-0.0.1-py3-none-any.whl size=28431 sha256=9c2843c7c5fdd56f8fccaa557f52245ba096ec3be4a24b60073e6b832226985c
#   Stored in directory: /private/var/folders/dj/q5s8lngd1msdbb76w1tn9x1r0000gn/T/pip-ephem-wheel-cache-6xed07cm/wheels/42/b8/65/3eee5f57277de325bcb9f7cd38797e88955e2920896f1714d9
# Successfully built fforma-FedericoGarza
# Installing collected packages: fforma-FedericoGarza
# Successfully installed fforma-FedericoGarza-0.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
from fforma.fforma import *
from fforma import FFORMA
from fforma.r_models import (
    ARIMA,
    ETS,
    ThetaF,
    Naive,
    SeasonalNaive
)
from fforma.meta_model import (
    MetaModels,
    temp_holdout,
    calc_errors,
    get_prediction_panel
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-62d564f0c519> in <module>
# ----> 1 from fforma.fforma import *
#       2 from fforma import FFORMA
#       3 from fforma.r_models import (
#       4     ARIMA,
#       5     ETS,
#
# /opt/anaconda3/envs/Fuzzy_FTS/lib/python3.6/site-packages/fforma/fforma.py in <module>
#       6 import multiprocessing as mp
#       7
# ----> 8 from src.meta_model import MetaModels
#       9 from src.meta_evaluation import calc_errors
#      10 from src.base_models import SeasonalNaive, Naive2, RandomWalkDrift
#
# ModuleNotFoundError: No module named 'src'

# %%
df2=pd.read_csv("/Users/philippebeliveau/Desktop/Bureau/Notebook_Jupyter_R/Fuzzy_TS_Conformal_Prediction/Fuzzy_FTS/Electricity_data/daily-minimum-temperatures-in-me.csv")

# %%
df2['Date']=pd.to_datetime(df2['Date'])

df2.index=df2['Date']

df2.drop('Date',axis=1,inplace=True)

df2
# Out:
#             Daily minimum temperatures
# Date
# 1981-01-01                        20.7
# 1981-01-02                        17.9
# 1981-01-03                        18.8
# 1981-01-04                        14.6
# 1981-01-05                        15.8
# ...                                ...
# 1990-12-27                        14.0
# 1990-12-28                        13.6
# 1990-12-29                        13.5
# 1990-12-30                        15.7
# 1990-12-31                        13.0
#
# [3650 rows x 1 columns]

# %%
df2['Daily minimum temperatures']=pd.to_numeric(df2['Daily minimum temperatures'],errors='coerce')

# %%
x=df2.loc['1980':'1982']

x.plot(figsize=(15,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from pyFTS.common import Transformations

diff = Transformations.Differential(1)
fig = plt.subplots(figsize=(20,5))
plt.plot(diff.apply(df2['Daily minimum temperatures'].values), label="Temperature")
pass
